# %% [markdown]
# <a href="https://colab.research.google.com/github/isahibjit/Fooocus/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-telegram-bot
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.7/662.7 kB 12.9 MB/s eta 0:00:00
# ...

# %%
# !pip install pygit2==1.15.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 46.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.16.0
#     Uninstalling pygit2-1.16.0:
#       Successfully uninstalled pygit2-1.16.0
# ...

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/isahibjit/Fooocus
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6723, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6723 (delta 0), reused 1 (delta 0), pack-reused 6718 (from 1)
# Receiving objects: 100% (6723/6723), 33.26 MiB | 23.73 MiB/s, done.
# Resolving deltas: 100% (3874/3874), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 8.59MB/s]
# ...
